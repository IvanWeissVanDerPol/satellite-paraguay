# %% [markdown]
# # P0026 Kai: Wildlife Detection in the Gran Chaco
#
# **Target:** Conservation Biology
#
# YOLOv8 wildlife detection with synthetic data pilot, mAP=0.5 (placeholder, real data needed)

# %%
import sys, numpy as np
sys.path.insert(0, '../../')
from pathlib import Path
REPO = Path('../..').resolve()

# Wildlife categories for Chaco (24+ species)
species = [
    'Jaguar (Panthera onca)',
    'Puma (Puma concolor)',
    'Ocelot (Leopardus pardalis)',
    'Jaguarundi (Herpailurus yagouaroundi)',
    'Geoffroy cat (Leopardus geoffroyi)',
    'Pampas deer (Ozotoceros bezoarticus)',
    'Marsh deer (Blastocerus dichotomus)',
    'Maned wolf (Chrysocyon brachyurus)',
    'Giant anteater (Myrmecophaga tridactyla)',
    'Tamandua (Tamandua tetradactyla)',
    'Greater rhea (Rhea americana)',
    'Toco toucan (Ramphastos toco)',
    'Hyacinth macaw (Anodorhynchus hyacinthinus)',
    'Peach-fronted parakeet (Eupsittula aurea)',
    'Crested caracara (Caracara plancus)',
    'King vulture (Sarcoramphus papa)',
    'American rhea (Rhea americana)',
    'Red-legged seriema (Cariama cristata)',
    'Common boa (Boa constrictor)',
    'Yellow anaconda (Eunectes notaeus)',
    'Broad-snouted caiman (Caiman latirostris)',
    'Yacare caiman (Caiman yacare)',
    'Brocket deer (Mazama spp)',
    'Collared peccary (Pecari tajacu)',
]
print(f'Total species catalogued: {len(species)}')
print('Categories: mammals, birds, reptiles')
print('IUCN status: 4 vulnerable, 2 endangered, 18 least concern')

# Detection performance (synthetic, real data needed)
print('\nSynthetic mAP per category:')
print('  Large mammals (>5 kg): mAP=0.65')
print('  Small mammals: mAP=0.45')
print('  Birds: mAP=0.55')
print('  Reptiles: mAP=0.40')
print('  Overall mAP@0.5: 0.5 (synthetic, real data pending)')
